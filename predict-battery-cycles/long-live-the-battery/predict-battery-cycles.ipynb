# %%
# !python3 -m pip install -r drive/MyDrive/long-live-the-battery/requirements.txt &> /dev/null

# %%
# %%shell
# cd drive/MyDrive/long-live-the-battery/
# python3 -m trainer.task --model "full_cnn_model" --num-epochs 10
# Out:
# Using full cnn model!
# 2022-03-12 04:07:48.658473: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  Qdlin (InputLayer)             [(None, 20, 1000, 1  0           []
#                                 )]
#
#  cnn_detail (Conv2D)            (None, 20, 334, 32)  896         ['Qdlin[0][0]']
#
#  maxpool_detail (MaxPooling2D)  (None, 20, 167, 32)  0           ['cnn_detail[0][0]']
#
#  IR (InputLayer)                [(None, 20, 1)]      0           []
#
#  Discharge_time (InputLayer)    [(None, 20, 1)]      0           []
#
#  QD (InputLayer)                [(None, 20, 1)]      0           []
#
# ...

# %%
# %%shell
# cd drive/MyDrive/long-live-the-battery/
# python3 generate_json_samples.py
# Out:
# 2022-03-12 05:50:22.492967: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Created 6 sample files in samples/

# %%
# %%shell
# cd drive/MyDrive/long-live-the-battery/
# python3 predict.py
# Out:
# --> Loading Keras Model and Predicting
# 2022-03-12 05:52:49.276696: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# --> Predicting on sample_input_1.json
# Returning predictions:
# <class 'numpy.ndarray'>
# [[0.16227427 0.44812316]]
